# %% [markdown]
# <a href="https://colab.research.google.com/github/josecrespo89/Arduino-PID-Library/blob/master/actividad00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('http://pilas.exp.dc.uba.ar/datos/datos_1.csv')
display(df)
# Out:
#     ID       ApellidoNombre Genero  ...      Zodiaco HoroscopoChino         Toro
# 0    1    Marley, Valentina      F  ...    Sagitario         Conejo  1023.200756
# 1    2      Gonzalez, María      F  ...        Virgo            NaN  1035.208593
# 2    3       Sosa, Santiago      M  ...        Libra          Gallo   909.341347
# 3    4        Leloir, Tomás      M  ...        Aries           Rata  1031.125285
# 4    5    Houssay, Santiago      M  ...          Leo      Serpiente   993.740374
# 5    6    San Martin, Lucía      F  ...        Tauro        Caballo   743.609141
# 6    7         Marley, Juan      M  ...       Piscis            NaN   860.368046
# 7    8     Romero, Catalina      F  ...  Capricornio            NaN   680.555630
# 8    9        Lopes, Thiago      M  ...        Virgo            NaN   937.013405
# 9   10             Leloir,       M  ...  Capricornio            NaN   864.145216
# 10  11      Sadosky, Matías      M  ...  Capricornio      Serpiente  1059.585285
# ...

# %%
df.describe()
# Out:
#              ID       Edad    Avance  ...  AlturaMama  AlturaPapa         Toro
# count  50.00000  50.000000  50.00000  ...   50.000000   50.000000    50.000000
# mean   25.50000  31.337540   3.22000  ...  160.706954  174.016034   881.415318
# std    14.57738   9.763996   1.40393  ...    4.986934    5.042421   260.254734
# min     1.00000  19.233024   1.00000  ...  150.408400  160.351100   334.554586
# 25%    13.25000  23.211020   3.00000  ...  157.934650  170.393375   680.016262
# 50%    25.50000  30.481054   3.00000  ...  160.699750  174.461700   862.256631
# 75%    37.75000  37.761245   5.00000  ...  163.320625  177.297175  1062.542053
# max    50.00000  57.231094   5.00000  ...  171.462200  185.064500  1450.316131
#
# [8 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              50 non-null     int64
#  1   ApellidoNombre  50 non-null     object
#  2   Genero          50 non-null     object
#  3   Edad            50 non-null     float64
#  4   Carrera         50 non-null     object
#  5   Avance          50 non-null     int64
#  6   Promedio        50 non-null     float64
#  7   NotaBaja        50 non-null     int64
#  8   Inglés          50 non-null     int64
#  9   Francés         50 non-null     int64
#  10  Cuadro          50 non-null     object
#  11  Altura          50 non-null     float64
#  12  Peso            50 non-null     float64
#  13  AlturaMama      50 non-null     float64
#  14  ContexturaMama  50 non-null     object
#  15  AlturaPapa      50 non-null     float64
#  16  Zodiaco         48 non-null     object
# ...

# %% [markdown]
# Cuál es la altura más alta registrada?

# %%
df['Altura'].max()
# Out:
# 186.9005

# %% [markdown]
# Y la altura más baja?

# %%
df['Altura'].min()
# Out:
# 154.0849

# %% [markdown]
# Cuál es la edad promedio?

# %%
df['Edad'].mean()
# Out:
# 31.337539878856038

# %% [markdown]
# Hay algún dato que falte ?

# %%
df.isna().any().any()
# Out:
# True

# %% [markdown]
# Obtener la columna que contiene las alturas . Escribir un código que calcule la altura promedio, la más alta y la más baja.

# %%
print('Altura maxima:', df['Altura'].max())
print('Altura minima:', df['Altura'].min())
print('Altura promedio', df['Altura'].mean())
# Out:
# Altura maxima: 186.9005
# Altura minima: 154.0849
# Altura promedio 168.51055800000003
